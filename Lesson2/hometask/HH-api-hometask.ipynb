# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/da-python/python-for-data-analytics/blob/main/Lesson2/hometask/HH-api-hometask.ipynb)

# %% [markdown]
# # Задание
# * Скачать все вакансии СБЕРа с ХХ (у апи есть ограничение в 2000, а также captcha подумайте как их можно обойти)
# * Извлеките все описания этих вакансий
# * Создайте DataFrame  добавьте поле skills
# * Переведите даты публикаций в datetime
# * Постройте график опубликованных вакансий по датам
# * Переведите даты в дни недели, и определите день недели, в который больше всего публикуют вакансий
# * Найдите те вакансии с использованием python, которые вам интересны
# * Определите по полю skills какие навыки больше всего востребованы для этих вакансий
# * Постройте график наиболее востребованных навыков для аналитика данных

# %% [markdown]
# https://github.com/hhru/api

# %%
import requests
from tqdm.auto import tqdm
import pandas as pd

# %%
sber = '3529'
page = 1
num_per_page = 100
moscow = 1
url = f'https://api.hh.ru/vacancies?employer_id={sber}&page={page}&per_page={num_per_page}&area={moscow}'

# %%
url = f'https://api.hh.ru/vacancies'
params = {
    'employer_id':sber,
    'page':page,
    'per_page':num_per_page,
    'area':moscow,
}
res = requests.get(url, params=params)

# %%
res.json()
# Out:
# {'items': [{'id': '67872660',
#    'premium': False,
#    'name': 'Junior DevOps-инженер (CI/CD)',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 150000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32',
#     'description': None,
#     'lat': 55.740421,
#     'lng': 37.532071,
#     'raw': 'Москва, Кутузовский проспект, 32',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'МЦК',
#      'station_id': '95.536',
#      'line_id': '95',
#      'lat': 55.740833,
#      'lng': 37.533333},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '823806'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-18T14:11:32+0300',
#    'created_at': '2022-07-18T14:11:32+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67872660',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67872660?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67872660/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67872660',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Обязательно: Высшее техническое образование в области IT, интерес к DevOps. Желательно: ∙ Понимание принципов функционирования ОС семейства UNIX. ∙ Опыт работы с...',
#     'responsibility': 'Вакансия DevOps-инженера в команде Release&DevOps кластера «Межбанковские расчёты». В кластере несколько команд, которые занимаются развитием межбанковских (в т...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67885227',
#    'premium': False,
#    'name': 'NET разработчик',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-18T17:02:53+0300',
#    'created_at': '2022-07-18T17:02:53+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67885227',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67885227?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67885227/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67885227',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Отличное знание C#. Фреймворки .NET, .NET Core. Отличное знание MS SQL. REST API. Опыт использования ELK. Опыт командной разработки. ',
#     'responsibility': 'разработка и развитие систем автоматизации внутренних процессов. Исправление ошибок, интеграция с системами. Активное участие в развитии продуктов компании.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66534291',
#    'premium': False,
#    'name': 'Golang Developer',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-02T11:09:15+0300',
#    'created_at': '2022-07-02T11:09:15+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66534291',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66534291?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66534291/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66534291',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Уверенное знание Golang. Опыт разработки промышленных решений на Golang, имеющих внедрения в промышленную эксплуатацию. Опыт с REST и RPV фреймворками...',
#     'responsibility': 'Разработка решений для обработки данных и организации доступа к данным экосистемы. Участие в разработке Solution архитектур и определении технологических стеков.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66589132',
#    'premium': False,
#    'name': 'Junior java-разработчик',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-01T13:44:01+0300',
#    'created_at': '2022-07-01T13:44:01+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66589132',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66589132?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66589132/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66589132',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Java SE 8/11. Spring framework. MyBatis. React. Высшее законченное техническое образование (это важно!). Уверенное знание Java Core (опыт работы...',
#     'responsibility': 'Мы разрабатываем системы управления кредитными и операционными рисками для Блока «Риски» Сбербанка. Мы минимизируем кредитные риски банка, тем самым уменьшая...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67080364',
#    'premium': False,
#    'name': 'Frontend-разработчик',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-22T12:43:01+0300',
#    'created_at': '2022-06-22T12:43:01+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67080364',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67080364?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67080364/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67080364',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Знание TypeScript от 2-3 лет. Опыт разработки web-решений в команде от 5 лет. Знание ReactJS. Знание HTML, CSS. ',
#     'responsibility': 'Разработка клиентского кода на языке TypeScript/JavaScript. Разработка UI по существующему UI Kit (используем Ant Design). Участие в разработке архитектуры...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67297641',
#    'premium': False,
#    'name': 'QA engineer',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-28T15:38:51+0300',
#    'created_at': '2022-06-28T15:38:51+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67297641',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67297641?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67297641/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67297641',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт в ручном тестировании от 1 года. - Уверенное знание принципов и методологий тестирования. - Уверенные знания по работе c JIRA. - ',
#     'responsibility': 'Ручное тестирование web и mobile приложений.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67690176',
#    'premium': False,
#    'name': 'Кредитный инспектор в отдел администрирования кредитов',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-12T11:13:55+0300',
#    'created_at': '2022-07-12T11:13:55+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67690176',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67690176?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67690176/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67690176',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование по направлению: финансы или экономика. Опыт работы не менее 1 года в релевантной должности. Умение пользоваться необходимыми методическими...',
#     'responsibility': 'Организация подписания полного комплекта кредитно-обеспечительной документации со стороны Банка (включая документацию LMA), в т.ч. соглашений о работе со...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '48624489',
#    'premium': False,
#    'name': 'IOS developer (SberDevices)',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-04T16:29:19+0300',
#    'created_at': '2022-07-04T16:29:19+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48624489',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/48624489?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/48624489/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/48624489',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Вместе формируем единые правила, гайды, стили и инструменты. Быстро растём за счёт высокого качества Code Review. Декларативная верстка на UIKit...',
#     'responsibility': 'Дизайн-система и Backend-driven UI. Уже разрабатывали под iOS.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67715358',
#    'premium': False,
#    'name': 'QA engineer',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-12T18:18:39+0300',
#    'created_at': '2022-07-12T18:18:39+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67715358',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67715358?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67715358/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67715358',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Знание и понимание методологии разработки Agile. Знание видов функционального и нефункционального тестирования. Знание техник тест-дизайна и умение их применять. ',
#     'responsibility': 'Мы команда в Сбере, которая занимается клиентским сервисом для заказа и формирования документов по уже оформленным продуктам (например есть кредит...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67868477',
#    'premium': False,
#    'name': 'QA Engineer',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-18T13:16:51+0300',
#    'created_at': '2022-07-18T13:16:51+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67868477',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67868477?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67868477/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67868477',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Знание методов и методик тестирования. Диагностика проблем — по логам, описанию пользователей и другим косвенным признакам. Умение четко описать найденную проблему. ',
#     'responsibility': 'Составление тест-кейсов и ведение тестовой документации. Ручное функциональное, интеграционное, регрессионное тестирование. Обработкой результатов тестирования, локализация найденных дефектов, описание их...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67910846',
#    'premium': False,
#    'name': 'Frontend-разработчик',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-19T12:03:25+0300',
#    'created_at': '2022-07-19T12:03:25+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67910846',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67910846?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67910846/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67910846',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Выпуск в опытную и промышленную эксплуатацию. Умение разбираться в чужом коде, писать чистый и понятный код для других разработчиков. ',
#     'responsibility': 'Проектирование доработок в существующих и запускаемых с нуля продуктах. Разработка новой и улучшение существующей функциональности. Технологический анализ. Сопровождение продуктов и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67525339',
#    'premium': False,
#    'name': 'Главный специалист в Отдел Статических Данных (Middle-office)',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-06T09:35:21+0300',
#    'created_at': '2022-07-06T09:35:21+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67525339',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67525339?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67525339/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67525339',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Знание западного и российского фондового рынка, законодательства о РЦБ, требований ФСФР. Опыт работы в миддл-офисе или бэк-офисе от...',
#     'responsibility': 'Внесение статических данных Клиентов, Бенефициаров и поверенных: настройка, обновление и поддержание данных в АС Банка, обеспечение точности и качества ввода...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67471249',
#    'premium': False,
#    'name': 'Специалист по внутренним коммуникациям',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Новоданиловская набережная',
#     'building': '10',
#     'description': None,
#     'lat': 55.695905,
#     'lng': 37.625361,
#     'raw': 'Москва, Новоданиловская набережная, 10',
#     'metro': {'station_name': 'Тульская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.142',
#      'line_id': '9',
#      'lat': 55.70961,
#      'lng': 37.622569},
#     'metro_stations': [{'station_name': 'Тульская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.142',
#       'line_id': '9',
#       'lat': 55.70961,
#       'lng': 37.622569}],
#     'id': '146841'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-04T17:37:31+0300',
#    'created_at': '2022-07-04T17:37:31+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67471249',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67471249?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67471249/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67471249',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы QA инженером или понимание специфики работы QA инженеров. Развитые коммуникативные навыки. Аналитические склад ума, умение анализировать большие объемы...',
#     'responsibility': 'Работать с производственными командами для тиражирования изменений в методологии и инструментах тестирования. Собирать и отрабатывать обратную связь от клиентов Кластера...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67410135',
#    'premium': False,
#    'name': 'Старший специалист по взысканию',
#    'department': {'id': '3529-3529-stat', 'name': 'Сбер. Начало карьеры'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 106000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-21T15:12:46+0300',
#    'created_at': '2022-07-21T15:12:46+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67410135',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67410135?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67410135/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67410135',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Специалист со средним специальным, неоконченным высшим или высшим образованием. Готов к разъездной работе. Умеешь справляться со стрессом и ориентирован на...',
#     'responsibility': 'Ездить к клиентам по месту жительства или работы. Вести переговоры с клиентами банка с целью возврата просроченной задолженности (лично и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67746233',
#    'premium': False,
#    'name': 'Инженер-программист в центр робототехники Сбера',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 220000, 'to': 250000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-13T15:29:41+0300',
#    'created_at': '2022-07-13T15:29:41+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67746233',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67746233?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67746233/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67746233',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Знание С++ и многопоточного программирования. Знание Python. Хорошие знания Linux (опыт системного программирования). Опыт работы с протоколами коммуникации (Например: zmq...',
#     'responsibility': 'Разрабатывать систему управления флотом роботов. Разрабатывать алгоритмы маршрутизации, диспетчеризации, взаимодействия и управления роботами и другими устройствами. Разрабатывать набор десктопных и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67978547',
#    'premium': False,
#    'name': 'Account-manager SberDevices',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-20T11:14:23+0300',
#    'created_at': '2022-07-20T11:14:23+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67978547',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67978547?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67978547/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67978547',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы с отчетными документами и сопровождение договоров (расходных, доходных, лицензионных) от 3-х лет. Знание документооборота. Ответственность, самостоятельность, грамотность...',
#     'responsibility': 'Составление ежемесячных/ежеквартальных отчетов по договорам (расходные, доходные, лицензионные) и обработка входящих отчетов от партнеров. Сбор первичных данных для составления...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55421333',
#    'premium': False,
#    'name': 'Технический руководитель',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-11T17:58:43+0300',
#    'created_at': '2022-07-11T17:58:43+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55421333',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55421333?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55421333/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55421333',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Имеете опыт принятия архитектурных решений. Имеете опыт руководства техническими специалистами. Имеете опыт выявления и закрытия технологических рисков. Принимали участие во...',
#     'responsibility': 'Нести ответственность за техническое состояние и стабильную работу АС. Взаимодействовать с проектными командами. Принимать руководящие решения, касающиеся сотрудников. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67300477',
#    'premium': False,
#    'name': 'Инженер по тестированию',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-28T16:28:15+0300',
#    'created_at': '2022-06-28T16:28:15+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67300477',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67300477?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67300477/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67300477',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'От кандидата ожидаем умение проводить функциональное и UI-тестирование сервисов. Создавать и развивать инструменты автоматизации.',
#     'responsibility': 'Начинающего специалиста по тестированию, который будет принимать участие в отслеживании и контроле качества выпускаемого продукта. Заниматься функциональным тестированием бэкенда сервисов. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67471058',
#    'premium': False,
#    'name': 'UI/UX Дизайнер',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 290000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-18T11:51:25+0300',
#    'created_at': '2022-07-18T11:51:25+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67471058',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67471058?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67471058/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67471058',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Наличие портфолио. Использование Figma от 2х лет. Уверенная работа с auto layout, компонентами, вариантами. Умение рисовать иконки. ',
#     'responsibility': 'Разработка/доработка User flow. Общение с пользователями, проведение опросов фокус-групп по удобству и необходимому функционалу. Презентация и защита UX...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67914790',
#    'premium': False,
#    'name': 'Методолог по управлению недвижимостью',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-19T13:01:34+0300',
#    'created_at': '2022-07-19T13:01:34+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67914790',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67914790?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67914790/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67914790',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование (юридическое), желаемые ВУЗы: МГУ, ВШЭ, МГЮА, МГИМО, СПбГУ, РШЧП. Опыт работы по специальности от 5 лет. ',
#     'responsibility': 'Подготовка нормативных и распорядительных документов по процессам управления недвижимостью. Консультирование подразделений по вопросам оформления прав на недвижимость и сделок с...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67235538',
#    'premium': False,
#    'name': 'Продуктовый дизайнер',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-27T10:56:20+0300',
#    'created_at': '2022-06-27T10:56:20+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67235538',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67235538?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67235538/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67235538',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Отличное знание Figma. Опыт работы с дизайн-системами, создания компонентов. Опытом работы над мобильными приложениям.',
#     'responsibility': 'Помогать продуктовым командам проектировать новые сервисы и улучшать старые. Доносить критику до agile-команд в конструктивном ключе. Синхронизировать команды между...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67648231',
#    'premium': False,
#    'name': 'IOS разработчик (Кредитные карты)',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-11T11:16:19+0300',
#    'created_at': '2022-07-11T11:16:19+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67648231',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67648231?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67648231/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67648231',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт разработки iOS приложений от 1 года. Уверенное знание Swift. Знания ObjC будут плюсом.',
#     'responsibility': 'Писать эффективный код на Swift. Проектировать UI по дизайн-макетам. Анализировать и исправлять дефекты. Участвовать в рабочих коммуникациях внутри Agile...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67890738',
#    'premium': False,
#    'name': 'Стажер CV (AI LAB)',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 50000, 'to': 57700, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32',
#     'description': None,
#     'lat': 55.740421,
#     'lng': 37.532071,
#     'raw': 'Москва, Кутузовский проспект, 32',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'МЦК',
#      'station_id': '95.536',
# ...
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Предлагать продукты и услуги Сбера. Консультировать клиентов по возникающим вопросам. Помогать клиентам оформлять услуги и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67968884',
#    'premium': False,
#    'name': 'Frontend-разработчик (Парус)',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-20T08:40:58+0300',
#    'created_at': '2022-07-20T08:40:58+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67968884',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67968884?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67968884/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67968884',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Отличные знания JavaScript Core (типы данных, функции, прототипы, наследование, классы, промисы, async/await, обработка ошибок, работа с DOM, события браузера...',
#     'responsibility': 'Участие в разработке продукта от анализа до выхода в промышленную эксплуатацию. Совместная работа с разработчиками и бизнесом. Проведение код ревью...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67289493',
#    'premium': False,
#    'name': 'Технический менеджер проекта Compute',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 400000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-18T11:51:25+0300',
#    'created_at': '2022-07-18T11:51:25+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67289493',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67289493?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67289493/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67289493',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Имеете опыт участия в инфраструктурных или продуктовых проектах. Обладаете аналитическими навыками, владеете Python или SQL. Умеете общаться на одном языке...',
#     'responsibility': 'Организовывать рабочие процессы команды и следить за их прозрачностью. Детально знать продукт: пользовательские сценарии, процессы релизов, его архитектуру, инструментарий вокруг...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67752108',
#    'premium': False,
#    'name': 'Администратор зала',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-13T18:03:48+0300',
#    'created_at': '2022-07-13T18:03:48+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67752108',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67752108?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67752108/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67752108',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование. Коммуникабельность. Внимательность к деталям. Опыт работы от 1 года в сфере обслуживания и консультирования физических лиц. ',
#     'responsibility': 'Контроль чистоты и порядка в зоне ожидания клиентов. Контроль входящей/исходящей корреспонденции и звонков. Встреча и первичное обслуживание VIP клиентов...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67826237',
#    'premium': False,
#    'name': 'Продуктовый дизайнер (UX/UI)',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-15T19:23:29+0300',
#    'created_at': '2022-07-15T19:23:29+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67826237',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67826237?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67826237/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67826237',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Имеешь опыт работы на должности UX/UI-дизайнера с аналогичными функциями от 2 лет. Обладаешь знанием Figma для создания макетов...',
#     'responsibility': 'Разработка концепции и реализация дизайна на основе бизнес-требований. Проектирование пользовательских интерфейсов. Разработка прототипов инкрементов продукта и экранных форм. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67550910',
#    'premium': False,
#    'name': 'QA engineer',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-06T18:12:58+0300',
#    'created_at': '2022-07-06T18:12:58+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67550910',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67550910?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67550910/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67550910',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Знание теории тестирования и жизненного цикла ПО. Опыт работы с РБД - Основные знания SQL запросов (JOIN, SELECT и т.д). ',
#     'responsibility': 'Верификация задач из беклога по компонентам в Jira. Регрессионное тестирование API и тестирование нового функционала. Работа с тестовой моделью (написание...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67256751',
#    'premium': False,
#    'name': 'Android-разработчик, проект СберИнвестор',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-27T15:41:36+0300',
#    'created_at': '2022-06-27T15:41:36+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67256751',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67256751?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67256751/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67256751',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Имеешь опыт разработки Android приложений. Знаешь Kotlin и Android SDK. В курсе про шаблоны проектирования, и как их готовить. ',
#     'responsibility': 'Разрабатывать приложения СберИнвестор для Android в команде опытных разработчиков. Участвовать в принятии технических решений и планировании процесса разработки. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67909004',
#    'premium': False,
#    'name': 'QA Engineer',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-19T11:35:27+0300',
#    'created_at': '2022-07-19T11:35:27+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67909004',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67909004?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67909004/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67909004',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Знания теории тестирования, подходов к разработке. Общее понимание веб-технологий (HTML/CSS/JavaScript). Знание SQL на базовом уровне. "',
#     'responsibility': 'Функциональное тестирование веб и микросервисов. Разработка и поддержание в актуальном состоянии тестовой документации. Участие в анализе требований до начала разработки. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False}],
#  'found': 1226,
#  'pages': 13,
#  'per_page': 100,
#  'page': 1,
#  'clusters': None,
#  'arguments': None,
#  'alternate_url': 'https://hh.ru/search/vacancy?area=1&control_flag=vacancyBlacklistJoinEnabled%3ATrue&employer_id=3529&enable_snippets=true&items_on_page=100&page=1'}

# %%
res = requests.get(url)

# %%
print(res)
# Out:
# <Response [200]>

# %%
# res.json()

# %%
vacancies = res.json()
num_pages = vacancies.get('pages')
num_pages
# Out:
# 13

# %%
vacancies.keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'per_page', 'page', 'clusters', 'arguments', 'alternate_url'])

# %%
vacancies.get('items')[0]
# Out:
# {'id': '67137461',
#  'premium': False,
#  'name': 'Бизнес-аналитик',
#  'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#  'has_test': False,
#  'response_letter_required': False,
#  'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#  'salary': None,
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': None,
#  'response_url': None,
#  'sort_point_distance': None,
#  'published_at': '2022-06-23T18:53:32+0300',
#  'created_at': '2022-06-23T18:53:32+0300',
#  'archived': False,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67137461',
#  'insider_interview': None,
#  'url': 'https://api.hh.ru/vacancies/67137461?host=hh.ru',
#  'adv_response_url': 'https://api.hh.ru/vacancies/67137461/adv_response?host=hh.ru',
#  'alternate_url': 'https://hh.ru/vacancy/67137461',
#  'relations': [],
#  'employer': {'id': '3529',
#   'name': 'СБЕР',
#   'url': 'https://api.hh.ru/employers/3529',
#   'alternate_url': 'https://hh.ru/employer/3529',
#   'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#    '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#    '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#   'trusted': True},
#  'snippet': {'requirement': 'Опыт работы в должности бизнес-аналитика или технического писателя от 1 года. Опыт проведения любых пользовательских исследований. Опыт описания бизнес...',
#   'responsibility': 'Развитие собственной экосистемы переводов. Автоматизация кредитного процесса и транзакционных операций. Разрабатывать новые и улучшать существующие бизнес-процессы. Участвовать в разработке...'},
#  'contacts': None,
#  'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#  'working_days': [],
#  'working_time_intervals': [],
#  'working_time_modes': [],
#  'accept_temporary': False}

# %%
v = vacancies.get('items')

# %%
# v[0].get('')

# %%
vacancies.keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'per_page', 'page', 'clusters', 'arguments', 'alternate_url'])

# %%
vacancies = res.json()
num_pages = vacancies.get('pages')
vacancy_ids = [el.get('id') for el in vacancies.get('items')]

# %%
vacancies.keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'per_page', 'page', 'clusters', 'arguments', 'alternate_url'])

# %%
vnum  = vacancies.get('pages')

# %%
all_vacancy_ids= []
for i in tqdm(range(vnum)):
    url = f'https://api.hh.ru/vacancies?employer_id={sber}&page={i}&per_page={num_per_page}&area={moscow}'
    res = requests.get(url)
    vacancies = res.json()
    vacancy_ids = [el.get('id') for el in vacancies.get('items')]
    all_vacancy_ids.extend(vacancy_ids)
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
len(all_vacancy_ids)
# https://api.hh.ru/vacancies/66634517
# Out:
# 1226

# %%
vacs = []
for vac_id in tqdm(all_vacancy_ids):
    url = f'https://api.hh.ru/vacancies/{vac_id}'
    res = requests.get(url)
    vacs.append(res.json())
# Out:
#   0%|          | 0/1226 [00:00<?, ?it/s]

# %%
res = requests.get(url)

# %%
res.json().keys()
# Out:
# dict_keys(['id', 'premium', 'billing_type', 'relations', 'name', 'insider_interview', 'response_letter_required', 'area', 'salary', 'type', 'address', 'allow_messages', 'experience', 'schedule', 'employment', 'department', 'contacts', 'description', 'branded_description', 'vacancy_constructor_template', 'key_skills', 'accept_handicapped', 'accept_kids', 'archived', 'response_url', 'specializations', 'professional_roles', 'code', 'hidden', 'quick_responses_allowed', 'driver_license_types', 'accept_incomplete_resumes', 'employer', 'published_at', 'created_at', 'initial_created_at', 'negotiations_url', 'suitable_resumes_url', 'apply_alternate_url', 'has_test', 'test', 'alternate_url', 'working_days', 'working_time_intervals', 'working_time_modes', 'accept_temporary', 'languages'])

# %%
res.json().get('key_skills')
# Out:
# []

# %%
[{'name':'SQL'},{'name':'Python'},{'name':'Git'}]

# %%
[x.get('name') for x in [{'name':'SQL'},{'name':'Python'},{'name':'Git'}]]
# Out:
# ['SQL', 'Python', 'Git']

# %%
vacs[0]
# Out:
# {'id': '53361761',
#  'premium': False,
#  'billing_type': {'id': 'standard', 'name': 'Стандарт'},
#  'relations': [],
#  'name': 'Клиентский менеджер малого и микробизнеса',
#  'insider_interview': None,
#  'response_letter_required': False,
#  'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#  'salary': {'from': 93900, 'to': None, 'currency': 'RUR', 'gross': True},
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': None,
#  'allow_messages': True,
#  'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#  'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#  'employment': {'id': 'full', 'name': 'Полная занятость'},
#  'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#  'contacts': None,
#  'description': '<p>Клиентский менеджер малого и микробизнеса – важная позиция в Сбербанке. Это эксперт, который помогает предпринимателю на старте и в развитии бизнеса. На этой позиции важно установить контакт с клиентом, с интересом и подробно расспросить о его бизнесе и предложить необходимые продукты. В этом тебе поможет планшет с программой индивидуального подбора продуктовых предложений.</p> <p> </p> <p>Позиция клиентского менеджера подойдет тем, кто хочет работать с корпоративными клиентами и профессионально развиваться. Она предполагает как вертикальную карьеру, так и возможность «горизонтального роста»: переход в смежные специальности или в другие отделения и города. Если ты стремишься к профессиональному росту, присоединяйся к команде малого и микробизнеса Сбербанка.</p> <p><strong>Задачи:</strong></p> <p>- консультировать корпоративных клиентов по продуктам банка и экосистемы</p> <p>- обслуживать юридические лица при открытии расчётного счета</p> <p>- формировать потребность клиента на комплексное обслуживание в банке</p> <p>- продавать банковские продукты и услуги</p> <p>- обучать клиентов функционалу и использованию продуктов и услуг банка</p> <p>- оформлять документацию по сделкам</p> <p>- помогать клиентам взаимодействовать с подразделениями банка.</p> <p><strong>Ждем от кандидата:</strong></p> <p>- высшее образование (финансы/банки, экономика/бухгалтерия)</p> <p>- опыт в сфере продаж или обслуживания клиентов от 1 года</p> <p>- грамотная и структурированная речь</p> <p>- умение находить общий язык и располагать к себе собеседника</p> <p>- многозадачность и организованность.</p> <p><strong>Работа в Сбере – это:</strong></p> <ul> <li>стабильный оклад и социальная поддержка сотрудников</li> <li>официальное оформление с первого дня</li> <li>мобильная связь и корпоративный ipad</li> <li>оплата транспортных расходов</li> <li>расширенный ДМС с первого дня и льготное страхование для близких</li> <li>бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров: Okko, Сбер Маркет, Delivery Club, Самокат, Сбер Еаптека и других</li> <li>ипотека выгоднее на 4% для каждого сотрудника.</li> </ul> <p> </p> <p><strong>Присоединяйся к команде Сбера!</strong></p>',
#  'branded_description': '\n<style>\n.swiper-container {\n    margin: 0 auto;\n    position: relative;\n    overflow: hidden;\n    list-style: none;\n    padding: 0;\n    z-index: 1;\n}\n\n.swiper-container-no-flexbox .swiper-slide {\n    float: left;\n}\n\n.swiper-container-vertical>.swiper-wrapper {\n    -webkit-box-orient: vertical;\n    -webkit-box-direction: normal;\n    -ms-flex-direction: column;\n    flex-direction: column;\n}\n\n.swiper-wrapper {\n    position: relative;\n    width: 100%;\n    height: 100%;\n    z-index: 1;\n    display: -webkit-box;\n    display: -ms-flexbox;\n    display: flex;\n    -webkit-transition-property: -webkit-transform;\n    transition-property: -webkit-transform;\n    -o-transition-property: transform;\n    transition-property: transform;\n    transition-property: transform, -webkit-transform;\n    -webkit-box-sizing: content-box;\n    box-sizing: content-box;\n}\n\n.swiper-container-android .swiper-slide,\n.swiper-wrapper {\n    -webkit-transform: translate3d(0px, 0, 0);\n    transform: translate3d(0px, 0, 0);\n}\n\n.swiper-container-multirow>.swiper-wrapper {\n    -ms-flex-wrap: wrap;\n    flex-wrap: wrap;\n}\n\n.swiper-container-free-mode>.swiper-wrapper {\n    -webkit-transition-timing-function: ease-out;\n    -o-transition-timing-function: ease-out;\n    transition-timing-function: ease-out;\n    margin: 0 auto;\n}\n\n.swiper-slide {\n    -ms-flex-negative: 0;\n    flex-shrink: 0;\n    width: 100%;\n    height: 100%;\n    position: relative;\n    -webkit-transition-property: -webkit-transform;\n    transition-property: -webkit-transform;\n    -o-transition-property: transform;\n    transition-property: transform;\n    transition-property: transform, -webkit-transform;\n}\n\n.swiper-slide-invisible-blank {\n    visibility: hidden;\n}\n\n.swiper-container-autoheight,\n.swiper-container-autoheight .swiper-slide {\n    height: auto;\n}\n\n.swiper-container-autoheight .swiper-wrapper {\n    -webkit-box-align: start;\n    -ms-flex-align: start;\n    align-items: flex-start;\n    -webkit-transition-property: height, -webkit-transform;\n    transition-property: height, -webkit-transform;\n    -o-transition-property: transform, height;\n    transition-property: transform, height;\n    transition-property: transform, height, -webkit-transform;\n}\n\n.swiper-container-fade.swiper-container-free-mode .swiper-slide {\n    -webkit-transition-timing-function: ease-out;\n    -o-transition-timing-function: ease-out;\n    transition-timing-function: ease-out;\n}\n\n.swiper-container-fade .swiper-slide {\n    pointer-events: none;\n    -webkit-transition-property: opacity;\n    -o-transition-property: opacity;\n    transition-property: opacity;\n}\n\n.swiper-container-fade .swiper-slide .swiper-slide {\n    pointer-events: none;\n}\n\n.swiper-container-fade .swiper-slide-active,\n.swiper-container-fade .swiper-slide-active .swiper-slide-active {\n    pointer-events: auto;\n}\n\n.swiper-container-3d {\n    -webkit-perspective: 1200px;\n    perspective: 1200px;\n}\n\n.swiper-container-3d .swiper-wrapper,\n.swiper-container-3d .swiper-slide,\n.swiper-container-3d .swiper-slide-shadow-left,\n.swiper-container-3d .swiper-slide-shadow-right,\n.swiper-container-3d .swiper-slide-shadow-top,\n.swiper-container-3d .swiper-slide-shadow-bottom,\n.swiper-container-3d .swiper-cube-shadow {\n    -webkit-transform-style: preserve-3d;\n    transform-style: preserve-3d;\n}\n\n.swiper-container-3d .swiper-slide-shadow-left,\n.swiper-container-3d .swiper-slide-shadow-right,\n.swiper-container-3d .swiper-slide-shadow-top,\n.swiper-container-3d .swiper-slide-shadow-bottom {\n    position: absolute;\n    left: 0;\n    top: 0;\n    width: 100%;\n    height: 100%;\n    pointer-events: none;\n    z-index: 10;\n}\n\n.swiper-container-3d .swiper-slide-shadow-left {\n    background-image: -webkit-gradient(linear, right top, left top, from(rgba(0, 0, 0, 0.5)), to(rgba(0, 0, 0, 0)));\n    background-image: -webkit-linear-gradient(rig ...
#  'vacancy_constructor_template': None,
#  'key_skills': [{'name': 'Активные продажи'},
#   {'name': 'Проведение презентаций'},
#   {'name': 'Привлечение клиентов'},
#   {'name': 'Навыки продаж'}],
#  'accept_handicapped': False,
#  'accept_kids': False,
#  'archived': False,
#  'response_url': None,
#  'specializations': [{'id': '17.242',
#    'name': 'Прямые продажи',
#    'profarea_id': '17',
#    'profarea_name': 'Продажи'},
#   {'id': '17.196',
#    'name': 'Оптовая торговля',
#    'profarea_id': '17',
#    'profarea_name': 'Продажи'},
#   {'id': '17.149',
#    'name': 'Менеджер по работе с клиентами',
#    'profarea_id': '17',
#    'profarea_name': 'Продажи'}],
#  'professional_roles': [{'id': '105',
#    'name': 'Руководитель отдела клиентского обслуживания'}],
#  'code': None,
#  'hidden': False,
#  'quick_responses_allowed': False,
#  'driver_license_types': [],
#  'accept_incomplete_resumes': False,
#  'employer': {'id': '3529',
#   'name': 'СБЕР',
#   'url': 'https://api.hh.ru/employers/3529',
#   'alternate_url': 'https://hh.ru/employer/3529',
#   'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#    '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#    '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#   'trusted': True},
#  'published_at': '2022-06-27T12:47:08+0300',
#  'created_at': '2022-06-27T12:47:08+0300',
#  'initial_created_at': '2022-03-04T10:23:27+0300',
#  'negotiations_url': None,
#  'suitable_resumes_url': None,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=53361761',
#  'has_test': False,
#  'test': None,
#  'alternate_url': 'https://hh.ru/vacancy/53361761',
#  'working_days': [],
#  'working_time_intervals': [],
#  'working_time_modes': [],
#  'accept_temporary': False,
#  'languages': []}

# %%
df = pd.json_normalize(vacs)

# %%
df.head()
# Out:
#          id  premium relations  \
# 0  53361761    False        []
# 1  55415805    False        []
# 2  55415496    False        []
# 3  45790891    False        []
# 4  67349462    False        []
#
#                                                 name insider_interview  \
# 0          Клиентский менеджер малого и микробизнеса              None
# 1                     Менеджер по работе с клиентами              None
# 2                  Клиентский менеджер прямых продаж              None
# 3  Менеджер по работе с ключевыми клиентами малог...              None
# 4                        Старший клиентский менеджер              None
#
#    response_letter_required  address  allow_messages contacts  \
# 0                     False      NaN            True     None
# 1                     False      NaN            True     None
# 2                     False      NaN            True     None
# 3                     False      NaN            True     None
# 4                     False      NaN            True     None
#
#                                          description  ...  \
# 0  <p>Клиентский менеджер малого и микробизнеса –...  ...
# 1  <p>Сбер — лучший работодатель России. У нас бо...  ...
# 2  <p>Сбер — лучший работодатель России. У нас бо...  ...
# 3  <p>Сбер — лучший работодатель России. У нас бо...  ...
# 4  <p>Сбер — лучший работодатель России. У нас бо...  ...
#
#   address.metro.station_name address.metro.line_name address.metro.station_id  \
# 0                        NaN                     NaN                      NaN
# 1                        NaN                     NaN                      NaN
# 2                        NaN                     NaN                      NaN
# 3                        NaN                     NaN                      NaN
# 4                        NaN                     NaN                      NaN
#
#    address.metro.line_id  address.metro.lat  address.metro.lng  \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
#
#   address.metro_stations address.metro test.required immediate_redirect_url
# 0                    NaN           NaN           NaN                    NaN
# 1                    NaN           NaN           NaN                    NaN
# 2                    NaN           NaN           NaN                    NaN
# 3                    NaN           NaN           NaN                    NaN
# 4                    NaN           NaN           NaN                    NaN
#
# [5 rows x 84 columns]
